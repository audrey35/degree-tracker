# %%
from IPython.core.display import display

from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd

# %%
def url_to_html(url):
    # Source: https://realpython.com/python-web-scraping-practical-introduction/
    page = urlopen(url)  # open the url
    html = page.read().decode("utf-8")  # read the url
    return html

def html_to_text(html):
    soup = BeautifulSoup(html, "html.parser")  # parse html
    parsed = soup.get_text().replace("\n\n", "")  # remove superfluous newlines
    return parsed

# %%
# Source: https://realpython.com/python-web-scraping-practical-introduction/
with open("requirements_urls.txt", "r") as fp:
    lines = fp.readlines()
for line in lines:
    url = line.replace("\n", "")
    fname = url.split("/")[-2]
    html = url_to_html(url)
    parsed = html_to_text(html)
    soup = BeautifulSoup(html, "html.parser")
    test = soup.find_all("table")
    dfdict = []
    count = 0
    print("*****" + fname + "*****")
    for i in test:
        df = pd.read_html(str(i))  # this parses all the tables in webpages to a list
        df = pd.DataFrame(df[0])
        display(df)
        print()
# Out:
# *****computer-science-phd*****
#
#
#
#
#
#
#
# *****artificial-intelligence-ms*****
#
#
# *****data-science-ms*****
#
#
#
# *****data-science-align-ms*****
#
#
#
#
# *****robotics-ms*****
#
#
#
#
#
#
#
# *****computer-science-mscs*****
#
#
# *****computer-science-align-program-mscs*****
#
#
#
# *****cloud-software-development-graduate-certificate*****
#
# *****computer-science-graduate-certificate*****
#
# *****data-analytics-graduate-certificate*****
#
# *****cybersecurity-bachelors-degree-entrance-phd*****
#
#
#
#
#
#
# *****cybersecurity-ms*****
#
#
#
#
# *****cybersecurity-ms-align*****
#
#
#
#
#
# *****cybersecurity-graduate-certificate*****
#
#
# *****personal-health-informatics-phd*****
#
#
#
#
# *****health-informatics-ms*****
#
#
# *****health-informatics-management-exchange-graduate-certificate*****
#
# *****health-informatics-privacy-security-graduate-certificate*****
#
# *****health-informatics-software-engineering-graduate-certificate*****
#
# *****data-science-ms*****
#
#
#
# *****game-science-design-ms*****
#
#
#
#
# *****robotics-ms*****
#
#
#
#
#
#
#
# *****data-analytics-graduate-certificate*****
#                                                                   Code  \
# 0                                                        Breadth Areas
# 1   Complete one course from four of the five following breadth areas:
# 2                             Artificial Intelligence and Data Science
# 3                                                              CS 6140
# 4                                                              CS 7150
# 5                                                              CS 7200
# 6                                                              CS 7240
# 7                                             Human-Centered Computing
# 8                                                              CS 7340
# 9                                                              CS 7250
# 10                                                            Software
# 11                                                             CS 6410
# 12                                                             CS 7400
# 13                                                             CS 7430
# 14                                                             Systems
# 15                                                             CS 7600
# 16                                                             CS 7610
# 17                                                              Theory
# 18                                                             CS 7800
# 19                                                             CS 7805
# 20                                              Specialization Courses
# 21     Complete 8 semester hours from the specialization course lists.
#
#                                                                                Title  \
# 0                                                                      Breadth Areas
# 1                 Complete one course from four of the five following breadth areas:
# 2                                           Artificial Intelligence and Data Science
# 3                                                                   Machine Learning
# 4                                                                      Deep Learning
# 5                                           Statistical Methods for Computer Science
# 6   Principles of Scalable Data Management: Theory, Algorithms, and Database Systems
# 7                                                           Human-Centered Computing
# 8                                   Theory and Methods in Human Computer Interaction
# 9                                 Information Visualization: Theory and Applications
# 10                                                                          Software
# 11                                                                         Compilers
# 12                                     Intensive Principles of Programming Languages
# 13                                 Formal Specification, Verification, and Synthesis
# 14                                                                           Systems
# 15                                                        Intensive Computer Systems
# 16                                                Foundations of Distributed Systems
# 17                                                                            Theory
# 18                                                               Advanced Algorithms
# 19                                                             Theory of Computation
# 20                                                            Specialization Courses
# 21                   Complete 8 semester hours from the specialization course lists.
#
#     Hours
# 0     NaN
# 1    16.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    8.0
#                                                               Code  \
# 0                     Complete 24 semester hours in the following:
# 1  Note: Consult faculty adviser for the other acceptable courses.
# 2                               CS 5100 to CS 5850, except CS 5340
# 3                                               CS 6110 to CS 6810
# 4                                                          CS 7340
# 5                                                          CS 8982
#
#                                                              Title  Hours
# 0                     Complete 24 semester hours in the following:   24.0
# 1  Note: Consult faculty adviser for the other acceptable courses.    NaN
# 2                               CS 5100 to CS 5850, except CS 5340    NaN
# 3                                               CS 6110 to CS 6810    NaN
# 4                 Theory and Methods in Human Computer Interaction    NaN
# 5                                                         Readings    NaN
#                                                                                           Code  \
# 0  Upon achieving PhD candidacy, complete the following courses for two consecutive semesters:
# 1                                                                                      CS 9990
# 2                                                                                      CS 9991
# 3      For remaining semester(s), complete the following (repeatable) course until graduation:
# 4                                                                                      CS 9996
#
#                                                                                          Title  \
# 0  Upon achieving PhD candidacy, complete the following courses for two consecutive semesters:
# 1                                                                          Dissertation Term 1
# 2                                                                          Dissertation Term 2
# 3      For remaining semester(s), complete the following (repeatable) course until graduation:
# 4                                                                    Dissertation Continuation
#
#    Hours
# 0    NaN
# 1    0.0
# 2    0.0
# 3    NaN
# 4    NaN
#                        Code                                   Title  Hours
# 0   Artificial Intelligence                 Artificial Intelligence    NaN
# 1                   CS 5100  Foundations of Artificial Intelligence    NaN
# 2                   CS 5335             Robotic Science and Systems    NaN
# 3                   CS 6120             Natural Language Processing    NaN
# 4                   CS 6140                        Machine Learning    NaN
# ..                      ...                                     ...    ...
# 66                  CS 5150            Game Artificial Intelligence    NaN
# 67                  CS 5310                       Computer Graphics    NaN
# 68                  CS 5340              Computer/Human Interaction    NaN
# 69                  CS 5850                   Building Game Engines    NaN
# 70                  CS 7140               Advanced Machine Learning    NaN
#
# [71 rows x 3 columns]
#              Year 1
#                Fall            Hours           Spring          Hours.1
# 0    Breadth course                4   Breadth course                4
# 1     Core elective                4    Core elective                4
# 2               NaN                8              NaN                8
# 3            Year 2           Year 2           Year 2           Year 2
# 4              Fall            Hours           Spring            Hours
# 5    Breadth course                4   Breadth course                4
# 6     Open elective                4    Open elective                4
# 7               NaN                8              NaN                8
# 8            Year 3           Year 3           Year 3           Year 3
# 9              Fall            Hours           Spring            Hours
# 10          CS 9990                0          CS 9991                0
# 11          CS 8982                8          CS 8982                8
# 12              NaN                8              NaN                8
# 13           Year 4           Year 4           Year 4           Year 4
# 14             Fall            Hours           Spring            Hours
# 15          CS 9996                0          CS 9996                0
# 16              NaN                0              NaN                0
# 17           Year 5           Year 5           Year 5           Year 5
# 18             Fall            Hours           Spring            Hours
# 19          CS 9996                0          CS 9996                0
# 20              NaN                0              NaN                0
# 21           Year 6           Year 6           Year 6           Year 6
# 22             Fall            Hours           Spring            Hours
# 23          CS 9996                0          CS 9996                0
# 24              NaN                0              NaN                0
# 25  Total Hours: 48  Total Hours: 48  Total Hours: 48  Total Hours: 48
#                                                    Code  \
# 0  Consult your faculty adviser for acceptable courses.
#
#                                                   Title  Hours
# 0  Consult your faculty adviser for acceptable courses.     16
#                                                                                                       Code  \
# 0                                                                                                  CS 9990
# 1                                                                                                  CS 9991
# 2  Upon achieving PhD candidacy, complete the following (repeatable) course for two consecutive semesters:
# 3                                                                                                  CS 8982
# 4              For any remaining semester(s), complete the following (repeatable) course until graduation:
# 5                                                                                                  CS 9996
#
#                                                                                                      Title  \
# 0                                                                                      Dissertation Term 1
# 1                                                                                      Dissertation Term 2
# 2  Upon achieving PhD candidacy, complete the following (repeatable) course for two consecutive semesters:
# 3                                                                                                 Readings
# 4              For any remaining semester(s), complete the following (repeatable) course until graduation:
# 5                                                                                Dissertation Continuation
#
#    Hours
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
#                         Code  \
# 0               Intelligence
# 1                    CS 5100
# 2                    CS 5170
# 3  Programing and Algorithms
# 4                    CS 5010
# 5                    CS 5800
# 6           Machine Learning
# 7                    CS 6140
#
#                                                     Title  Hours
# 0                                            Intelligence    NaN
# 1                  Foundations of Artificial Intelligence    4.0
# 2  Artificial Intelligence for Human-Computer Interaction    4.0
# 3                               Programing and Algorithms    NaN
# 4                             Programming Design Paradigm    4.0
# 5                                              Algorithms    4.0
# 6                                        Machine Learning    NaN
# 7                                        Machine Learning    4.0
#                                                                Code  \
# 0                                                    Specialization
# 1   Complete two courses from one of the following specializations:
# 2                                                            Vision
# 3                                                           CS 5330
# 4                                                           CS 7180
# 5                                                         EECE 5639
# 6                                           Intelligent Interaction
# 7                                                           CS 5150
# 8                                                           CS 7340
# 9                                  Robotics and Agent-Based Systems
# 10                                                          CS 5335
# 11                                                        EECE 5550
# 12                                                        EECE 5554
# 13                                                 Machine Learning
# 14                                                          CS 7140
# 15                                                     or EECE 7397
# 16                                                          DS 5230
# 17                               Knowledge Management and Reasoning
# 18                                                          CS 6120
# 19                                                          CS 6200
# 20                                                          CS 6220
# 21                                              Additional Elective
# 22                                   Complete one of the following:
# 23                                                          CS 6800
# 24                                                          CS 7180
# 25                                                          CS 7990
# 26                                                          CS 8674
# 27                                                        EECE 7337
# 28                                                        GSND 5110
# 29                                                         LAW 7639
# 30                                                        LING 5100
# 31                                                        PHIL 5010
#
#                                                               Title  \
# 0                                                    Specialization
# 1   Complete two courses from one of the following specializations:
# 2                                                            Vision
# 3                           Pattern Recognition and Computer Vision
# 4                         Special Topics in Artificial Intelligence
# 5                                                   Computer Vision
# 6                                           Intelligent Interaction
# 7                                      Game Artificial Intelligence
# 8                  Theory and Methods in Human Computer Interaction
# 9                                  Robotics and Agent-Based Systems
# 10                                      Robotic Science and Systems
# 11                                                  Mobile Robotics
# 12                                  Robotics Sensing and Navigation
# 13                                                 Machine Learning
# 14                                        Advanced Machine Learning
# 15                                        Advanced Machine Learning
# 16                    Unsupervised Machine Learning and Data Mining
# 17                               Knowledge Management and Reasoning
# 18                                      Natural Language Processing
# 19                                            Information Retrieval
# 20                                           Data Mining Techniques
# 21                                              Additional Elective
# 22                                   Complete one of the following:
# 23                                Application of Information Theory
# 24                        Special Topics in Artificial Intelligence
# 25                                                           Thesis
# 26                                                 Master’s Project
# 27                                               Information Theory
# 28                                         Game Design and Analysis
# 29                                                     Internet Law
# 30                                      Introduction to Linguistics
# 31                                                        AI Ethics
#
#                         Hours
# 0                         NaN
# 1                           8
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15  Advanced Machine Learning
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                          4
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# 30                        NaN
# 31                        NaN
#                                              Code  \
# 0                                      Algorithms
# 1   Complete 4 semester hours from the following:
# 2                                         CS 5800
# 3                                       EECE 7205
# 4                  Data Management and Processing
# 5                                         DS 5110
# 6                Machine Learning and Data Mining
# 7                                         DS 5220
# 8                                         DS 5230
# 9                  Presentation and Visualization
# 10                                        DS 5500
#
#                                                       Title  Hours
# 0                                                Algorithms    NaN
# 1             Complete 4 semester hours from the following:    4.0
# 2                                                Algorithms    NaN
# 3                      Fundamentals of Computer Engineering    NaN
# 4                            Data Management and Processing    NaN
# 5            Introduction to Data Management and Processing    4.0
# 6                          Machine Learning and Data Mining    NaN
# 7           Supervised Machine Learning and Learning Theory    4.0
# 8             Unsupervised Machine Learning and Data Mining    4.0
# 9                            Presentation and Visualization    NaN
# 10  Information Visualization: Applications in Data Science    4.0
#                                                 Code  \
# 0   Complete 12 semester hours from the following: 1
# 1                Khoury College of Computer Sciences
# 2                                            CS 5100
# 3                                            CS 5180
# 4                                            CS 5200
# 5                                            CS 5340
# 6                                            CS 5610
# 7                                            CS 6120
# 8                                            CS 6200
# 9                                            CS 6240
# 10                                           CS 6350
# 11                                           CS 6620
# 12                                           CS 7180
# 13                                           CS 7280
# 14                                           CS 7290
# 15                                           DS 7990
# 16                                           DS 7995
# 17                            College of Engineering
# 18                                         CIVE 7100
# 19                                         CIVE 7388
# 20                                         EECE 5639
# 21                                         EECE 5640
# 22                                         EECE 7337
# 23                                         EECE 7370
# 24                                         EECE 7397
# 25                                           IE 7275
# 26                                           IE 7280
# 27                                         INFO 7370
# 28         College of Social Sciences and Humanities
# 29                                         ECON 5140
# 30                                         PPUA 5261
# 31                                         PPUA 5262
# 32                                         PPUA 5263
# 33                                         PPUA 5266
# 34                                         PPUA 7237
# 35                                         POLS 7200
# 36                                         POLS 7201
# 37                                         POLS 7202
# 38                  D'Amore-McKim School of Business
# 39                                         BUSN 6320
# 40                                College of Science
# 41                                         PHYS 5116
# 42                                         PHYS 7305
# 43                                         PHYS 7321
# 44                                         PHYS 7331
# 45                  Bouvé College of Health Sciences
# 46                                         PHTH 5202
# 47                                         PHTH 5210
# 48                                         PHTH 6224
# 49                 College of Arts, Media and Design
# 50                                         GSND 5110
# 51                                         GSND 6350
#
#                                                               Title  Hours
# 0                  Complete 12 semester hours from the following: 1   12.0
# 1                               Khoury College of Computer Sciences    NaN
# 2                            Foundations of Artificial Intelligence    NaN
# 3             Reinforcement Learning and Sequential Decision Making    NaN
# 4                                       Database Management Systems    NaN
# 5                                        Computer/Human Interaction    NaN
# 6                                                   Web Development    NaN
# 7                                       Natural Language Processing    NaN
# 8                                             Information Retrieval    NaN
# 9                              Large-Scale Parallel Data Processing    NaN
# 10                                       Empirical Research Methods    NaN
# 11                                  Fundamentals of Cloud Computing    NaN
# 12                        Special Topics in Artificial Intelligence    NaN
# 13                            Special Topics in Database Management    NaN
# 14                                   Special Topics in Data Science    NaN
# 15                                                           Thesis    NaN
# 16                                                          Project    NaN
# 17                                           College of Engineering    NaN
# 18                         Time Series and Geospatial Data Sciences    NaN
# 19                              Special Topics in Civil Engineering    NaN
# 20                                                  Computer Vision    NaN
# 21                                       High-Performance Computing    NaN
# 22                                               Information Theory    NaN
# 23                                         Advanced Computer Vision    NaN
# 24                                        Advanced Machine Learning    NaN
# 25                                       Data Mining in Engineering    NaN
# 26                               Statistical Methods in Engineering    NaN
# 27  Designing Advanced Data Architectures for Business Intelligence    NaN
# 28                        College of Social Sciences and Humanities    NaN
# 29                                             Applied Econometrics    NaN
# 30               Dynamic Modeling for Environmental Decision Making    NaN
# 31                                              Big Data for Cities    NaN
# 32     Geographic Information Systems for Urban and Regional Policy    NaN
# 33                                         Urban Theory and Science    NaN
# 34                       Advanced Spatial Analysis of Urban Systems    NaN
# 35                           Perspectives on Social Science Inquiry    NaN
# 36                                                  Research Design    NaN
# 37                                          Quantitative Techniques    NaN
# 38                                 D'Amore-McKim School of Business    NaN
# 39                                  Business Analytics Fundamentals    NaN
# 40                                               College of Science    NaN
# 41                                Complex Networks and Applications    NaN
# 42                                              Statistical Physics    NaN
# 43                                            Computational Physics    NaN
# 44                                             Network Science Data    NaN
# 45                                 Bouvé College of Health Sciences    NaN
# 46                                     Introduction to Epidemiology    NaN
# 47                                   Biostatistics in Public Health    NaN
# 48                                              Social Epidemiology    NaN
# 49                                College of Arts, Media and Design    NaN
# 50                                         Game Design and Analysis    NaN
# 51                                      Data-Driven Player Modeling    NaN
#    0  \
# 0  1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                1
# 0  Students taking electives worth less than 4 credits (i.e., Bouvé courses) should enroll for an accompanying data science project course in the same semester to bring the cumulative credits to 4. In order to earn this additional credit, students are expected to work with faculty to design an additional project in line with the curricular aims of their chosen elective and the data science core learning outcomes.
#                            Code  \
# 0                  Fundamentals
# 1            CS 5001and CS 5003
# 2           Discrete Structures
# 3                       CS 5002
# 4  Programming for Data Science
# 5                       DS 5010
# 6   Additional ALIGN Coursework
# 7                       DS 5020
#
#                                                                  Title  Hours
# 0                                                         Fundamentals    NaN
# 1  Intensive Foundations of Computer Scienceand Recitation for CS 5001    4.0
# 2                                                  Discrete Structures    NaN
# 3                                                  Discrete Structures    4.0
# 4                                         Programming for Data Science    NaN
# 5                         Introduction to Programming for Data Science    4.0
# 6                                          Additional ALIGN Coursework    NaN
# 7      Introduction to Linear Algebra and Probability for Data Science    4.0
#                                              Code  \
# 0                                      Algorithms
# 1   Complete 4 semester hours from the following:
# 2                                         CS 5800
# 3                                       EECE 7205
# 4                  Data Management and Processing
# 5                                         DS 5110
# 6                Machine Learning and Data Mining
# 7                                         DS 5220
# 8                                         DS 5230
# 9                  Presentation and Visualization
# 10                                        DS 5500
#
#                                                       Title  Hours
# 0                                                Algorithms    NaN
# 1             Complete 4 semester hours from the following:    4.0
# 2                                                Algorithms    NaN
# 3                      Fundamentals of Computer Engineering    NaN
# 4                            Data Management and Processing    NaN
# 5            Introduction to Data Management and Processing    4.0
# 6                          Machine Learning and Data Mining    NaN
# 7           Supervised Machine Learning and Learning Theory    4.0
# 8             Unsupervised Machine Learning and Data Mining    4.0
# 9                            Presentation and Visualization    NaN
# 10  Information Visualization: Applications in Data Science    4.0
#                                               Code  \
# 0   Complete 12 semester hours from the following:
# 1      College of Computer and Information Science
# 2                                          CS 5100
# 3                                          CS 5180
# 4                                          CS 5200
# 5                                          CS 5340
# 6                                          CS 5610
# 7                                          CS 6120
# 8                                          CS 6200
# 9                                          CS 6240
# 10                                         CS 6350
# 11                                         CS 6620
# 12                                         CS 7180
# 13                                         DS 7990
# 14                                         DS 7995
# 15                                         CS 7280
# 16                                         CS 7290
# 17                          College of Engineering
# 18                                       CIVE 7100
# 19                                       CIVE 7388
# 20                                       EECE 5639
# 21                                       EECE 5640
# 22                                       EECE 7337
# 23                                       EECE 7370
# 24                                       EECE 7397
# 25                                         IE 7275
# 26                                         IE 7280
# 27                                       INFO 7370
# 28       College of Social Sciences and Humanities
# 29                                       ECON 5140
# 30                                       PPUA 5261
# 31                                       PPUA 5262
# 32                                       PPUA 5263
# 33                                       PPUA 5266
# 34                                       PPUA 7237
# 35                                       POLS 7200
# 36                                       POLS 7201
# 37                                       POLS 7202
# 38                D'Amore-McKim School of Business
# 39                                       BUSN 6320
# 40                              College of Science
# 41                                       PHYS 5116
# 42                                       PHYS 7305
# 43                                       PHYS 7321
# 44                                       PHYS 7331
# 45                Bouvé College of Health Sciences
# 46                                       PHTH 5202
# 47                                       PHTH 5210
# 48                                       PHTH 6224
# 49               College of Arts, Media and Design
# 50                                       GSND 5110
# 51                                       GSND 6350
#
#                                                               Title  Hours
# 0                    Complete 12 semester hours from the following:   12.0
# 1                       College of Computer and Information Science    NaN
# 2                            Foundations of Artificial Intelligence    NaN
# 3             Reinforcement Learning and Sequential Decision Making    NaN
# 4                                       Database Management Systems    NaN
# 5                                        Computer/Human Interaction    NaN
# 6                                                   Web Development    NaN
# 7                                       Natural Language Processing    NaN
# 8                                             Information Retrieval    NaN
# 9                              Large-Scale Parallel Data Processing    NaN
# 10                                       Empirical Research Methods    NaN
# 11                                  Fundamentals of Cloud Computing    NaN
# 12                        Special Topics in Artificial Intelligence    NaN
# 13                                                           Thesis    NaN
# 14                                                          Project    NaN
# 15                            Special Topics in Database Management    NaN
# 16                                   Special Topics in Data Science    NaN
# 17                                           College of Engineering    NaN
# 18                         Time Series and Geospatial Data Sciences    NaN
# 19                              Special Topics in Civil Engineering    NaN
# 20                                                  Computer Vision    NaN
# 21                                       High-Performance Computing    NaN
# 22                                               Information Theory    NaN
# 23                                         Advanced Computer Vision    NaN
# 24                                        Advanced Machine Learning    NaN
# 25                                       Data Mining in Engineering    NaN
# 26                               Statistical Methods in Engineering    NaN
# 27  Designing Advanced Data Architectures for Business Intelligence    NaN
# 28                        College of Social Sciences and Humanities    NaN
# 29                                             Applied Econometrics    NaN
# 30               Dynamic Modeling for Environmental Decision Making    NaN
# 31                                              Big Data for Cities    NaN
# 32     Geographic Information Systems for Urban and Regional Policy    NaN
# 33                                         Urban Theory and Science    NaN
# 34                       Advanced Spatial Analysis of Urban Systems    NaN
# 35                           Perspectives on Social Science Inquiry    NaN
# 36                                                  Research Design    NaN
# 37                                          Quantitative Techniques    NaN
# 38                                 D'Amore-McKim School of Business    NaN
# 39                                  Business Analytics Fundamentals    NaN
# 40                                               College of Science    NaN
# 41                                Complex Networks and Applications    NaN
# 42                                              Statistical Physics    NaN
# 43                                            Computational Physics    NaN
# 44                                             Network Science Data    NaN
# 45                                 Bouvé College of Health Sciences    NaN
# 46                                     Introduction to Epidemiology    NaN
# 47                                   Biostatistics in Public Health    NaN
# 48                                              Social Epidemiology    NaN
# 49                                College of Arts, Media and Design    NaN
# 50                                         Game Design and Analysis    NaN
# 51                                      Data-Driven Player Modeling    NaN
#    0  \
# 0  1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                1
# 0  Students taking electives worth less than 4 credits (i.e., Bouvé courses) should enroll for an accompanying data science project course in the same semester to bring the cumulative credits to 4. In order to earn this additional credit, students are expected to work with faculty to design an additional project in line with the curricular aims of their chosen elective and the data science core learning outcomes.
#                                    Code  \
# 0                Mechanical Engineering
# 1        Complete one of the following:
# 2                               ME 5250
# 3                               ME 5659
# 4   Electrical and Computer Engineering
# 5        Complete one of the following:
# 6                             EECE 5550
# 7                             EECE 5554
# 8                      Computer Science
# 9        Complete one of the following:
# 10                              CS 5180
# 11                              CS 5335
#
#                                                     Title  Hours
# 0                                  Mechanical Engineering    NaN
# 1                          Complete one of the following:    4.0
# 2                             Robot Mechanics and Control    NaN
# 3                             Control Systems Engineering    NaN
# 4                     Electrical and Computer Engineering    NaN
# 5                          Complete one of the following:    4.0
# 6                                         Mobile Robotics    NaN
# 7                         Robotics Sensing and Navigation    NaN
# 8                                        Computer Science    NaN
# 9                          Complete one of the following:    4.0
# 10  Reinforcement Learning and Sequential Decision Making    NaN
# 11                            Robotic Science and Systems    NaN
#                                                                             Code  \
# 0                                                                Required Course
# 1       Complete additional ME course not used to fulfill the core requirements:
# 2                                                                        ME 5250
# 3                                                                        ME 5659
# 4                                                                        Options
# 5                                         Complete one of the following options:
# 6                                                             Course Work Option
# 7    Complete four of the following from the mechanical engineering course list.
# 8                                                                  Thesis Option
# 9                                                                        ME 7990
# 10    Complete two of the following from the mechanical engineering course list.
# 11                                                                Project Option
# 12                                                                       ME 7945
# 13  Complete three of the following from the mechanical engineering course list.
#
#                                                                            Title  \
# 0                                                                Required Course
# 1       Complete additional ME course not used to fulfill the core requirements:
# 2                                                    Robot Mechanics and Control
# 3                                                    Control Systems Engineering
# 4                                                                        Options
# 5                                         Complete one of the following options:
# 6                                                             Course Work Option
# 7    Complete four of the following from the mechanical engineering course list.
# 8                                                                  Thesis Option
# 9                                                                         Thesis
# 10    Complete two of the following from the mechanical engineering course list.
# 11                                                                Project Option
# 12                                                              Master’s Project
# 13  Complete three of the following from the mechanical engineering course list.
#
#     Hours
# 0     NaN
# 1     4.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5    16.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
#                                                                                          Code  \
# 0                                                                             Required Course
# 1                  Complete additional EECE course not used to fulfill the core requirements:
# 2                                                                                   EECE 5550
# 3                                                                                   EECE 5554
# 4                                                                                     Options
# 5                                                      Complete one of the following options:
# 6                                                                          Course Work Option
# 7    Complete four of the following from the electrical and computer engineering course list.
# 8                                                                               Thesis Option
# 9                                                                                   EECE 7990
# 10    Complete two of the following from the electrical and computer engineering course list.
# 11                                                                             Project Option
# 12                                                                                  EECE 7674
# 13  Complete three of the following from the electrical and computer engineering course list.
#
#                                                                                         Title  \
# 0                                                                             Required Course
# 1                  Complete additional EECE course not used to fulfill the core requirements:
# 2                                                                             Mobile Robotics
# 3                                                             Robotics Sensing and Navigation
# 4                                                                                     Options
# 5                                                      Complete one of the following options:
# 6                                                                          Course Work Option
# 7    Complete four of the following from the electrical and computer engineering course list.
# 8                                                                               Thesis Option
# 9                                                                                      Thesis
# 10    Complete two of the following from the electrical and computer engineering course list.
# 11                                                                             Project Option
# 12                                                                           Master’s Project
# 13  Complete three of the following from the electrical and computer engineering course list.
#
#     Hours
# 0     NaN
# 1     4.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5    16.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
#                                                                         Code  \
# 0                                                            Required Course
# 1   Complete additional CS course not used to fulfill the core requirements:
# 2                                                                    CS 5180
# 3                                                                    CS 5335
# 4                                                                    Options
# 5                                     Complete one of the following options:
# 6                                                         Course Work Option
# 7      Complete four of the following from the computer science course list.
# 8                                                              Thesis Option
# 9                                                                    CS 7990
# 10    Complete three of the following from the computer science course list.
# 11                                                            Project Option
# 12                                                                   CS 8674
# 13    Complete three of the following from the computer science course list.
#
#                                                                        Title  \
# 0                                                            Required Course
# 1   Complete additional CS course not used to fulfill the core requirements:
# 2                      Reinforcement Learning and Sequential Decision Making
# 3                                                Robotic Science and Systems
# 4                                                                    Options
# 5                                     Complete one of the following options:
# 6                                                         Course Work Option
# 7      Complete four of the following from the computer science course list.
# 8                                                              Thesis Option
# 9                           Thesis (complete twice for a total of 8 credits)
# 10    Complete three of the following from the computer science course list.
# 11                                                            Project Option
# 12                                                          Master’s Project
# 13    Complete three of the following from the computer science course list.
#
#     Hours
# 0     NaN
# ...
# 6                                                                                                               Design for Behavior and Experience
# 7                                                                                                                   Mobile Application Development
# 8                                                                                                                                  Web Development
# 9                                                                                                         Collecting, Storing, and Retrieving Data
# 10                                                                                                    Introduction to Data Mining/Machine Learning
# 11                                                                                                         Information Design and Visual Analytics
# 12                                                                                                                    Telling Your Story with Data
#
#     Hours
# 0     8.0
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
#              Year 1                                                     \
#                Fall            Hours           Spring          Hours.1
# 0         GSND 5110                4         Elective                4
# 1         GSND 5111                1         Elective                4
# 2         GSND 5130                4              NaN              NaN
# 3               NaN                9              NaN                8
# 4            Year 2           Year 2           Year 2           Year 2
# 5              Fall            Hours           Spring            Hours
# 6         GSND 5122                1         Elective                4
# 7         GSND 6330                4        GSND 7990                4
# 8          Elective                4              NaN              NaN
# 9               NaN                9              NaN                8
# 10  Total Hours: 34  Total Hours: 34  Total Hours: 34  Total Hours: 34
#
#
#    Summer Full Semester          Hours.2
# 0      Co-op (Optional)                0
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN                0
# 4                Year 2           Year 2
# 5                   NaN              NaN
# 6                   NaN              NaN
# 7                   NaN              NaN
# 8                   NaN              NaN
# 9                   NaN              NaN
# 10      Total Hours: 34  Total Hours: 34
#                                    Code  \
# 0                Mechanical Engineering
# 1        Complete one of the following:
# 2                               ME 5250
# 3                               ME 5659
# 4   Electrical and Computer Engineering
# 5        Complete one of the following:
# 6                             EECE 5550
# 7                             EECE 5554
# 8                      Computer Science
# 9        Complete one of the following:
# 10                              CS 5180
# 11                              CS 5335
#
#                                                     Title  Hours
# 0                                  Mechanical Engineering    NaN
# 1                          Complete one of the following:    4.0
# 2                             Robot Mechanics and Control    NaN
# 3                             Control Systems Engineering    NaN
# 4                     Electrical and Computer Engineering    NaN
# 5                          Complete one of the following:    4.0
# 6                                         Mobile Robotics    NaN
# 7                         Robotics Sensing and Navigation    NaN
# 8                                        Computer Science    NaN
# 9                          Complete one of the following:    4.0
# 10  Reinforcement Learning and Sequential Decision Making    NaN
# 11                            Robotic Science and Systems    NaN
#                                                                             Code  \
# 0                                                                Required Course
# 1       Complete additional ME course not used to fulfill the core requirements:
# 2                                                                        ME 5250
# 3                                                                        ME 5659
# 4                                                                        Options
# 5                                         Complete one of the following options:
# 6                                                             Course Work Option
# 7    Complete four of the following from the mechanical engineering course list.
# 8                                                                  Thesis Option
# 9                                                                        ME 7990
# 10    Complete two of the following from the mechanical engineering course list.
# 11                                                                Project Option
# 12                                                                       ME 7945
# 13  Complete three of the following from the mechanical engineering course list.
#
#                                                                            Title  \
# 0                                                                Required Course
# 1       Complete additional ME course not used to fulfill the core requirements:
# 2                                                    Robot Mechanics and Control
# 3                                                    Control Systems Engineering
# 4                                                                        Options
# 5                                         Complete one of the following options:
# 6                                                             Course Work Option
# 7    Complete four of the following from the mechanical engineering course list.
# 8                                                                  Thesis Option
# 9                                                                         Thesis
# 10    Complete two of the following from the mechanical engineering course list.
# 11                                                                Project Option
# 12                                                              Master’s Project
# 13  Complete three of the following from the mechanical engineering course list.
#
#     Hours
# 0     NaN
# 1     4.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5    16.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
#                                                                                          Code  \
# 0                                                                             Required Course
# 1                  Complete additional EECE course not used to fulfill the core requirements:
# 2                                                                                   EECE 5550
# 3                                                                                   EECE 5554
# 4                                                                                     Options
# 5                                                      Complete one of the following options:
# 6                                                                          Course Work Option
# 7    Complete four of the following from the electrical and computer engineering course list.
# 8                                                                               Thesis Option
# 9                                                                                   EECE 7990
# 10    Complete two of the following from the electrical and computer engineering course list.
# 11                                                                             Project Option
# 12                                                                                  EECE 7674
# 13  Complete three of the following from the electrical and computer engineering course list.
#
#                                                                                         Title  \
# 0                                                                             Required Course
# 1                  Complete additional EECE course not used to fulfill the core requirements:
# 2                                                                             Mobile Robotics
# 3                                                             Robotics Sensing and Navigation
# 4                                                                                     Options
# 5                                                      Complete one of the following options:
# 6                                                                          Course Work Option
# 7    Complete four of the following from the electrical and computer engineering course list.
# 8                                                                               Thesis Option
# 9                                                                                      Thesis
# 10    Complete two of the following from the electrical and computer engineering course list.
# 11                                                                             Project Option
# 12                                                                           Master’s Project
# 13  Complete three of the following from the electrical and computer engineering course list.
#
#     Hours
# 0     NaN
# 1     4.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5    16.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
#                                                                         Code  \
# 0                                                            Required Course
# 1   Complete additional CS course not used to fulfill the core requirements:
# 2                                                                    CS 5180
# 3                                                                    CS 5335
# 4                                                                    Options
# 5                                     Complete one of the following options:
# 6                                                         Course Work Option
# 7      Complete four of the following from the computer science course list.
# 8                                                              Thesis Option
# 9                                                                    CS 7990
# 10    Complete three of the following from the computer science course list.
# 11                                                            Project Option
# 12                                                                   CS 8674
# 13    Complete three of the following from the computer science course list.
#
#                                                                        Title  \
# 0                                                            Required Course
# 1   Complete additional CS course not used to fulfill the core requirements:
# 2                      Reinforcement Learning and Sequential Decision Making
# 3                                                Robotic Science and Systems
# 4                                                                    Options
# 5                                     Complete one of the following options:
# 6                                                         Course Work Option
# 7      Complete four of the following from the computer science course list.
# 8                                                              Thesis Option
# 9                           Thesis (complete twice for a total of 8 credits)
# 10    Complete three of the following from the computer science course list.
# 11                                                            Project Option
# 12                                                          Master’s Project
# 13    Complete three of the following from the computer science course list.
#
#     Hours
# 0     NaN
# 1     4.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5    16.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
#        Code                                            Title  Hours
# 0   IE 5630         Biosensor and Human Behavior Measurement    NaN
# 1   IE 7280               Statistical Methods in Engineering    NaN
# 2   IE 7315                        Human Factors Engineering    NaN
# 3   ME 5240          Computer Aided Design and Manufacturing    NaN
# 4   ME 5245                              Mechatronic Systems    NaN
# 5   ME 5250                      Robot Mechanics and Control    NaN
# 6   ME 5655                Dynamics and Mechanical Vibration    NaN
# 7   ME 5659                      Control Systems Engineering    NaN
# 8   ME 5665                     Musculoskeletal Biomechanics    NaN
# 9   ME 6200  Mathematical Methods for Mechanical Engineers 1    NaN
# 10  ME 6201  Mathematical Methods for Mechanical Engineers 2    NaN
# 11  ME 7210                        Elasticity and Plasticity    NaN
# 12  ME 7247                     Advanced Control Engineering    NaN
# 13  ME 7253                              Advanced Vibrations    NaN
#          Code                                                     Title  Hours
# 0   EECE 5550                                           Mobile Robotics    NaN
# 1   EECE 5552                                        Assistive Robotics    NaN
# 2   EECE 5554                           Robotics Sensing and Navigation    NaN
# 3   EECE 5580                                 Classical Control Systems    NaN
# 4   EECE 5639                                           Computer Vision    NaN
# 5   EECE 5642                                        Data Visualization    NaN
# 6   EECE 5644  Introduction to Machine Learning and Pattern Recognition    NaN
# 7   EECE 7150                                 Autonomous Field Robotics    NaN
# 8   EECE 7263                                         Humanoid Robotics    NaN
# 9   EECE 7323                            Numerical Optimization Methods    NaN
# 10  EECE 7337                                        Information Theory    NaN
# 11  EECE 7370                                  Advanced Computer Vision    NaN
# 12  EECE 7397                                 Advanced Machine Learning    NaN
#        Code                                            Title  Hours
# 0   CS 5006                                       Algorithms    NaN
# 1   CS 5100           Foundations of Artificial Intelligence    NaN
# 2   CS 5320                         Digital Image Processing    NaN
# 3   CS 5330          Pattern Recognition and Computer Vision    NaN
# 4   CS 5340                       Computer/Human Interaction    NaN
# 5   CS 6110                          Knowledge-Based Systems    NaN
# 6   CS 6120                      Natural Language Processing    NaN
# 7   CS 6130                              Affective Computing    NaN
# 8   CS 6140                                 Machine Learning    NaN
# 9   CS 6350                       Empirical Research Methods    NaN
# 10  CS 7140                        Advanced Machine Learning    NaN
# 11  CS 7170               Seminar in Artificial Intelligence    NaN
# 12  DS 5220  Supervised Machine Learning and Learning Theory    NaN
#         Code                                         Title  Hours
# 0    DA 5020      Collecting, Storing, and Retrieving Data      4
# 1    DA 5030  Introduction to Data Mining/Machine Learning      4
# 2  INSH 5301      Introduction to Computational Statistics      4
# 3  INSH 5302       Information Design and Visual Analytics      4
